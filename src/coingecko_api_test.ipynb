# %% [markdown]
# ## source
# ### https://www.coingecko.com/en/api/documentation
#
# ### https://github.com/man-c/pycoingecko

# %%
from pycoingecko import CoinGeckoAPI
cg = CoinGeckoAPI()

# %%
cg.ping()
# Out:
# {'gecko_says': '(V3) To the Moon!'}

# %%
cg.get_supported_vs_currencies()
# Out:
# ['btc',
#  'eth',
#  'ltc',
#  'bch',
#  'bnb',
#  'eos',
#  'xrp',
#  'xlm',
#  'link',
#  'dot',
#  'yfi',
#  'usd',
#  'aed',
#  'ars',
#  'aud',
#  'bdt',
#  'bhd',
#  'bmd',
#  'brl',
#  'cad',
#  'chf',
#  'clp',
#  'cny',
#  'czk',
#  'dkk',
#  'eur',
#  'gbp',
#  'hkd',
#  'huf',
#  'idr',
#  'ils',
#  'inr',
#  'jpy',
#  'krw',
#  'kwd',
#  'lkr',
#  'mmk',
#  'mxn',
#  'myr',
#  'ngn',
#  'nok',
#  'nzd',
#  'php',
#  'pkr',
#  'pln',
#  'rub',
#  'sar',
#  'sek',
#  'sgd',
#  'thb',
#  'try',
#  'twd',
#  'uah',
#  'vef',
#  'vnd',
#  'zar',
#  'xdr',
#  'xag',
#  'xau',
#  'bits',
#  'sats']

# %%
cg.get_coins_markets(vs_currency='USD')
# Out:
# [{'id': 'bitcoin',
#   'symbol': 'btc',
#   'name': 'Bitcoin',
#   'image': 'https://assets.coingecko.com/coins/images/1/large/bitcoin.png?1547033579',
#   'current_price': 50019,
#   'market_cap': 945919570803,
#   'market_cap_rank': 1,
#   'fully_diluted_valuation': 1050394454215,
#   'total_volume': 18795101997,
#   'high_24h': 51384,
#   'low_24h': 49775,
#   'price_change_24h': -979.28735451353,
#   'price_change_percentage_24h': -1.92024,
#   'market_cap_change_24h': -18819103256.323364,
#   'market_cap_change_percentage_24h': -1.95069,
#   'circulating_supply': 18911287.0,
#   'total_supply': 21000000.0,
#   'max_supply': 21000000.0,
#   'ath': 69045,
#   'ath_change_percentage': -27.52182,
#   'ath_date': '2021-11-10T14:24:11.849Z',
#   'atl': 67.81,
#   'atl_change_percentage': 73699.03951,
#   'atl_date': '2013-07-06T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2021-12-26T05:49:19.448Z'},
#  {'id': 'ethereum',
#   'symbol': 'eth',
#   'name': 'Ethereum',
#   'image': 'https://assets.coingecko.com/coins/images/279/large/ethereum.png?1595348880',
#   'current_price': 4034.8,
#   'market_cap': 479910707135,
#   'market_cap_rank': 2,
#   'fully_diluted_valuation': None,
#   'total_volume': 13393167230,
#   'high_24h': 4139.58,
#   'low_24h': 4019.8,
#   'price_change_24h': -22.486946853667,
#   'price_change_percentage_24h': -0.55424,
#   'market_cap_change_24h': -2392162176.5300903,
#   'market_cap_change_percentage_24h': -0.49599,
#   'circulating_supply': 118894298.749,
#   'total_supply': None,
#   'max_supply': None,
#   'ath': 4878.26,
#   'ath_change_percentage': -17.22672,
#   'ath_date': '2021-11-10T14:24:19.604Z',
#   'atl': 0.432979,
#   'atl_change_percentage': 932485.04409,
#   'atl_date': '2015-10-20T00:00:00.000Z',
#   'roi': {'times': 106.87653331695178,
#    'currency': 'btc',
#    'percentage': 10687.653331695177},
#   'last_updated': '2021-12-26T05:50:08.758Z'},
#  {'id': 'binancecoin',
#   'symbol': 'bnb',
#   'name': 'Binance Coin',
#   'image': 'https://assets.coingecko.com/coins/images/825/large/binance-coin-logo.png?1547034615',
#   'current_price': 540.99,
#   'market_cap': 91002261285,
#   'market_cap_rank': 3,
#   'fully_diluted_valuation': 91002261285,
#   'total_volume': 1271465546,
#   'high_24h': 551.2,
#   'low_24h': 537.32,
#   'price_change_24h': -4.829760359484,
#   'price_change_percentage_24h': -0.88486,
#   'market_cap_change_24h': -773287610.6957092,
#   'market_cap_change_percentage_24h': -0.84259,
#   'circulating_supply': 168137035.9,
#   'total_supply': 168137035.9,
#   'max_supply': 168137035.9,
#   'ath': 686.31,
#   'ath_change_percentage': -21.0889,
#   'ath_date': '2021-05-10T07:24:17.097Z',
#   'atl': 0.0398177,
#   'atl_change_percentage': 1360029.0935,
#   'atl_date': '2017-10-19T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2021-12-26T05:50:33.984Z'},
#  {'id': 'tether',
#   'symbol': 'usdt',
#   'name': 'Tether',
#   'image': 'https://assets.coingecko.com/coins/images/325/large/Tether-logo.png?1598003707',
#   'current_price': 1.0,
#   'market_cap': 78174367909,
#   'market_cap_rank': 4,
#   'fully_diluted_valuation': None,
#   'total_volume': 46033261426,
#   'high_24h': 1.01,
#   'low_24h': 0.995062,
#   'price_change_24h': 0.000392,
#   'price_change_percentage_24h': 0.03912,
#   'market_cap_change_24h': 431353561,
#   'market_cap_change_percentage_24h': 0.55485,
#   'circulating_supply': 77991578542.3877,
#   'total_supply': 77991578542.3877,
#   'max_supply': None,
#   'ath': 1.32,
#   'ath_change_percentage': -24.19836,
#   'ath_date': '2018-07-24T00:00:00.000Z',
#   'atl': 0.572521,
#   'atl_change_percentage': 75.1775,
#   'atl_date': '2015-03-02T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2021-12-26T05:47:51.847Z'},
#  {'id': 'solana',
#   'symbol': 'sol',
#   'name': 'Solana',
#   'image': 'https://assets.coingecko.com/coins/images/4128/large/solana.png?1640133422',
#   'current_price': 192.02,
#   'market_cap': 59323400551,
#   'market_cap_rank': 5,
#   'fully_diluted_valuation': None,
#   'total_volume': 1388929500,
#   'high_24h': 196.34,
#   'low_24h': 189.85,
#   'price_change_24h': -2.481492013219,
#   'price_change_percentage_24h': -1.2758,
#   'market_cap_change_24h': -731126503.1907043,
#   'market_cap_change_percentage_24h': -1.21744,
#   'circulating_supply': 308939652.168082,
#   'total_supply': 508180963.57,
#   'max_supply': None,
#   'ath': 259.96,
#   'ath_change_percentage': -26.09468,
#   'ath_date': '2021-11-06T21:54:35.825Z',
#   'atl': 0.500801,
#   'atl_change_percentage': 38263.27142,
#   'atl_date': '2020-05-11T19:35:23.449Z',
#   'roi': None,
#   'last_updated': '2021-12-26T05:50:10.956Z'},
#  {'id': 'cardano',
#   'symbol': 'ada',
#   'name': 'Cardano',
#   'image': 'https://assets.coingecko.com/coins/images/975/large/cardano.png?1547034860',
#   'current_price': 1.43,
#   'market_cap': 45805391217,
#   'market_cap_rank': 6,
#   'fully_diluted_valuation': 64280468172,
#   'total_volume': 909234166,
#   'high_24h': 1.47,
#   'low_24h': 1.4,
#   'price_change_24h': 0.02223931,
#   'price_change_percentage_24h': 1.5815,
#   'market_cap_change_24h': 713134403,
#   'market_cap_change_percentage_24h': 1.5815,
#   'circulating_supply': 32066390668.4135,
#   'total_supply': 45000000000.0,
#   'max_supply': 45000000000.0,
#   'ath': 3.09,
#   'ath_change_percentage': -53.70621,
#   'ath_date': '2021-09-02T06:00:10.474Z',
#   'atl': 0.01925275,
#   'atl_change_percentage': 7322.5677,
#   'atl_date': '2020-03-13T02:22:55.044Z',
#   'roi': None,
#   'last_updated': '2021-12-26T05:49:29.475Z'},
#  {'id': 'ripple',
#   'symbol': 'xrp',
#   'name': 'XRP',
#   'image': 'https://assets.coingecko.com/coins/images/44/large/xrp-symbol-white-128.png?1605778731',
#   'current_price': 0.917296,
#   'market_cap': 43604563024,
#   'market_cap_rank': 7,
#   'fully_diluted_valuation': 91729627257,
#   'total_volume': 2331278652,
#   'high_24h': 0.934244,
#   'low_24h': 0.910757,
#   'price_change_24h': -0.007159900447,
#   'price_change_percentage_24h': -0.7745,
#   'market_cap_change_24h': -340352773.27632904,
#   'market_cap_change_percentage_24h': -0.7745,
#   'circulating_supply': 47535964473.0,
#   'total_supply': 100000000000.0,
#   'max_supply': 100000000000.0,
#   'ath': 3.4,
#   'ath_change_percentage': -73.02793,
#   'ath_date': '2018-01-07T00:00:00.000Z',
#   'atl': 0.00268621,
#   'atl_change_percentage': 34023.67208,
#   'atl_date': '2014-05-22T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2021-12-26T05:48:22.018Z'},
#  {'id': 'usd-coin',
#   'symbol': 'usdc',
#   'name': 'USD Coin',
#   'image': 'https://assets.coingecko.com/coins/images/6319/large/USD_Coin_icon.png?1547042389',
#   'current_price': 1.0,
#   'market_cap': 42506532539,
#   'market_cap_rank': 8,
#   'fully_diluted_valuation': None,
#   'total_volume': 1943467069,
#   'high_24h': 1.01,
#   'low_24h': 0.993846,
#   'price_change_24h': 0.0003162,
#   'price_change_percentage_24h': 0.03157,
#   'market_cap_change_24h': 44975028,
#   'market_cap_change_percentage_24h': 0.10592,
#   'circulating_supply': 42422465244.379,
#   'total_supply': 42463558371.4053,
#   'max_supply': None,
#   'ath': 1.17,
#   'ath_change_percentage': -14.48913,
#   'ath_date': '2019-05-08T00:40:28.300Z',
#   'atl': 0.891848,
#   'atl_change_percentage': 12.43971,
#   'atl_date': '2021-05-19T13:14:05.611Z',
#   'roi': None,
#   'last_updated': '2021-12-26T05:48:08.115Z'},
#  {'id': 'terra-luna',
#   'symbol': 'luna',
#   'name': 'Terra',
#   'image': 'https://assets.coingecko.com/coins/images/8284/large/luna1557227471663.png?1567147072',
#   'current_price': 96.92,
#   'market_cap': 35284926089,
#   'market_cap_rank': 9,
#   'fully_diluted_valuation': 96916518874,
#   'total_volume': 2474204736,
#   'high_24h': 101.39,
#   'low_24h': 95.86,
#   'price_change_24h': -0.429466965626,
#   'price_change_percentage_24h': -0.44118,
#   'market_cap_change_24h': -248278407.51968384,
#   'market_cap_change_percentage_24h': -0.69872,
#   'circulating_supply': 364075458.954687,
#   'total_supply': 836410222.366436,
#   'max_supply': 1000000000.0,
#   'ath': 101.39,
#   'ath_change_percentage': -4.21978,
#   'ath_date': '2021-12-25T18:33:50.427Z',
#   'atl': 0.121798,
#   'atl_change_percentage': 79633.01862,
#   'atl_date': '2020-03-18T17:03:01.083Z',
#   'roi': None,
#   'last_updated': '2021-12-26T05:49:21.676Z'},
#  {'id': 'polkadot',
#   'symbol': 'dot',
#   'name': 'Polkadot',
#   'image': 'https://assets.coingecko.com/coins/images/12171/large/polkadot.png?1639712644',
#   'current_price': 28.69,
#   'market_cap': 30647267435,
#   'market_cap_rank': 10,
#   'fully_diluted_valuation': None,
#   'total_volume': 672220868,
#   'high_24h': 29.47,
#   'low_24h': 28.21,
#   'price_change_24h': 0.244645,
#   'price_change_percentage_24h': 0.86005,
#   'market_cap_change_24h': 271801284,
#   'market_cap_change_percentage_24h': 0.89481,
#   'circulating_supply': 1068212834.87795,
#   'total_supply': 1149161126.88407,
#   'max_supply': None,
#   'ath': 54.98,
#   'ath_change_percentage': -47.78104,
#   'ath_date': '2021-11-04T14:10:09.301Z',
#   'atl': 2.7,
#   'atl_change_percentage': 964.35326,
#   'atl_date': '2020-08-20T05:48:11.359Z',
#   'roi': None,
#   'last_updated': '2021-12-26T05:50:26.840Z'},
#  {'id': 'avalanche-2',
#   'symbol': 'AVAX',
#   'name': 'Avalanche',
#   'image': 'https://assets.coingecko.com/coins/images/12559/large/coin-round-red.png?1604021818',
#   'current_price': 111.85,
#   'market_cap': 27144434420,
#   'market_cap_rank': 11,
#   'fully_diluted_valuation': 80357752643,
#   'total_volume': 768944118,
#   'high_24h': 117.1,
#   'low_24h': 110.39,
#   'price_change_24h': -2.827851898072,
#   'price_change_percentage_24h': -2.46593,
#   'market_cap_change_24h': -610711970.3633156,
#   'market_cap_change_percentage_24h': -2.20036,
#   'circulating_supply': 243212286.799941,
#   'total_supply': 377752194.4695483,
#   'max_supply': 720000000.0,
#   'ath': 144.96,
#   'ath_change_percentage': -22.93825,
#   'ath_date': '2021-11-21T14:18:56.538Z',
#   'atl': 2.8,
#   'atl_change_percentage': 3888.11473,
#   'atl_date': '2020-12-31T13:15:21.540Z',
#   'roi': None,
#   'last_updated': '2021-12-26T05:50:19.720Z'},
#  {'id': 'dogecoin',
#   'symbol': 'doge',
#   'name': 'Dogecoin',
#   'image': 'https://assets.coingecko.com/coins/images/5/large/dogecoin.png?1547792256',
#   'current_price': 0.188135,
#   'market_cap': 24960012812,
#   'market_cap_rank': 12,
#   'fully_diluted_valuation': None,
#   'total_volume': 1084399977,
#   'high_24h': 0.193857,
#   'low_24h': 0.187343,
#   'price_change_24h': -0.004641733118,
#   'price_change_percentage_24h': -2.40783,
#   'market_cap_change_24h': -613212039.0068054,
#   'market_cap_change_percentage_24h': -2.39787,
#   'circulating_supply': 132670764299.894,
#   'total_supply': None,
#   'max_supply': None,
#   'ath': 0.731578,
#   'ath_change_percentage': -74.25228,
#   'ath_date': '2021-05-08T05:08:23.458Z',
#   'atl': 8.69e-05,
#   'atl_change_percentage': 216650.95078,
#   'atl_date': '2015-05-06T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2021-12-26T05:48:20.741Z'},
#  {'id': 'shiba-inu',
#   'symbol': 'shib',
#   'name': 'Shiba Inu',
#   'image': 'https://assets.coingecko.com/coins/images/11939/large/shiba.png?1622619446',
#   'current_price': 3.736e-05,
#   'market_cap': 20516174658,
#   'market_cap_rank': 13,
#   'fully_diluted_valuation': None,
#   'total_volume': 1023732563,
#   'high_24h': 3.829e-05,
#   'low_24h': 3.706e-05,
#   'price_change_24h': -6.91436e-07,
#   'price_change_percentage_24h': -1.81712,
#   'market_cap_change_24h': -372119719.3093529,
#   'market_cap_change_percentage_24h': -1.78147,
#   'circulating_supply': 549149953506533.7,
#   'total_supply': 1000000000000000.0,
#   'max_supply': None,
#   'ath': 8.616e-05,
#   'ath_change_percentage': -56.58683,
#   'ath_date': '2021-10-28T03:54:55.568Z',
#   'atl': 5.6e-11,
#   'atl_change_percentage': 66359060.03928,
#   'atl_date': '2020-11-28T11:26:25.838Z',
#   'roi': None,
#   'last_updated': '2021-12-26T05:50:11.143Z'},
#  {'id': 'matic-network',
#   'symbol': 'matic',
#   'name': 'Polygon',
#   'image': 'https://assets.coingecko.com/coins/images/4713/large/matic-token-icon.png?1624446912',
#   'current_price': 2.69,
#   'market_cap': 18513321030,
#   'market_cap_rank': 14,
#   'fully_diluted_valuation': 26936733438,
#   'total_volume': 1653149944,
#   'high_24h': 2.74,
#   'low_24h': 2.51,
#   'price_change_24h': 0.181426,
#   'price_change_percentage_24h': 7.22167,
#   'market_cap_change_24h': 1248374885,
#   'market_cap_change_percentage_24h': 7.23069,
#   'circulating_supply': 6872890164.27,
#   'total_supply': 10000000000.0,
#   'max_supply': 10000000000.0,
#   'ath': 2.74,
#   'ath_change_percentage': -1.90664,
#   'ath_date': '2021-12-23T19:50:10.036Z',
#   'atl': 0.00314376,
#   'atl_change_percentage': 85318.93621,
#   'atl_date': '2019-05-10T00:00:00.000Z',
#   'roi': {'times': 1023.210396881719,
#    'currency': 'usd',
#    'percentage': 102321.0396881719},
#   'last_updated': '2021-12-26T05:48:11.865Z'},
#  {'id': 'crypto-com-chain',
#   'symbol': 'cro',
#   'name': 'Crypto.com Coin',
#   'image': 'https://assets.coingecko.com/coins/images/7310/large/cypto.png?1547043960',
#   'current_price': 0.616986,
#   'market_cap': 15586929204,
#   'market_cap_rank': 15,
#   'fully_diluted_valuation': None,
#   'total_volume': 399700937,
#   'high_24h': 0.662435,
#   'low_24h': 0.609739,
#   'price_change_24h': -0.037984961637,
#   'price_change_percentage_24h': -5.79949,
#   'market_cap_change_24h': -959614605.9328327,
#   'market_cap_change_percentage_24h': -5.79949,
#   'circulating_supply': 25263013692.0,
#   'total_supply': 30263013692.0,
#   'max_supply': None,
#   'ath': 0.965407,
#   'ath_change_percentage': -36.00984,
#   'ath_date': '2021-11-24T15:53:54.855Z',
#   'atl': 0.0121196,
#   'atl_change_percentage': 4997.24444,
#   'atl_date': '2019-02-08T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2021-12-26T05:48:36.048Z'},
#  {'id': 'binance-usd',
#   'symbol': 'busd',
#   'name': 'Binance USD',
#   'image': 'https://assets.coingecko.com/coins/images/9576/large/BUSD.png?1568947766',
#   'current_price': 1.0,
#   'market_cap': 14843217174,
#   'market_cap_rank': 16,
#   'fully_diluted_valuation': None,
#   'total_volume': 3133902929,
#   'high_24h': 1.01,
#   'low_24h': 0.995625,
#   'price_change_24h': -0.000365233757,
#   'price_change_percentage_24h': -0.03643,
#   'market_cap_change_24h': -5410048.524795532,
#   'market_cap_change_percentage_24h': -0.03643,
#   'circulating_supply': 14812564321.03,
#   'total_supply': 14812564321.03,
#   'max_supply': None,
#   'ath': 1.15,
#   'ath_change_percentage': -13.13631,
#   'ath_date': '2020-03-13T02:35:42.953Z',
#   'atl': 0.901127,
#   'atl_change_percentage': 11.2589,
#   'atl_date': '2021-05-19T13:04:37.445Z',
#   'roi': None,
#   'last_updated': '2021-12-26T05:48:22.235Z'},
#  {'id': 'wrapped-bitcoin',
#   'symbol': 'wbtc',
#   'name': 'Wrapped Bitcoin',
#   'image': 'https://assets.coingecko.com/coins/images/7598/large/wrapped_bitcoin_wbtc.png?1548822744',
#   'current_price': 49980,
#   'market_cap': 12936846158,
#   'market_cap_rank': 17,
#   'fully_diluted_valuation': 12936846158,
#   'total_volume': 269118514,
#   'high_24h': 51196,
#   'low_24h': 49762,
#   'price_change_24h': -1013.55907057169,
#   'price_change_percentage_24h': -1.98762,
#   'market_cap_change_24h': -272090582.5210037,
#   'market_cap_change_percentage_24h': -2.0599,
#   'circulating_supply': 258840.12476808,
#   'total_supply': 258840.12476808,
#   'max_supply': 258840.12476808,
#   'ath': 70643,
#   'ath_change_percentage': -29.20986,
#   'ath_date': '2021-11-10T14:40:19.650Z',
#   'atl': 3139.17,
#   'atl_change_percentage': 1493.04877,
#   'atl_date': '2019-04-02T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2021-12-26T05:50:25.629Z'},
#  {'id': 'litecoin',
#   'symbol': 'ltc',
#   'name': 'Litecoin',
#   'image': 'https://assets.coingecko.com/coins/images/2/large/litecoin.png?1547033580',
#   'current_price': 154.96,
#   'market_cap': 10734311681,
#   'market_cap_rank': 18,
#   'fully_diluted_valuation': 13016450598,
#   'total_volume': 996383225,
#   'high_24h': 163.78,
#   'low_24h': 153.82,
#   'price_change_24h': -7.10899716774,
#   'price_change_percentage_24h': -4.38646,
#   'market_cap_change_24h': -491293210.12314034,
#   'market_cap_change_percentage_24h': -4.37654,
#   'circulating_supply': 69272508.2334713,
#   'total_supply': 84000000.0,
#   'max_supply': 84000000.0,
#   'ath': 410.26,
#   'ath_change_percentage': -62.21093,
#   'ath_date': '2021-05-10T03:13:07.904Z',
#   'atl': 1.15,
#   'atl_change_percentage': 13394.74625,
#   'atl_date': '2015-01-14T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2021-12-26T05:47:53.652Z'},
#  {'id': 'algorand',
#   'symbol': 'algo',
#   'name': 'Algorand',
#   'image': 'https://assets.coingecko.com/coins/images/4380/large/download.png?1547039725',
#   'current_price': 1.6,
#   'market_cap': 10162284372,
#   'market_cap_rank': 19,
#   'fully_diluted_valuation': 16000010444,
#   'total_volume': 284850132,
#   'high_24h': 1.61,
#   'low_24h': 1.54,
#   'price_change_24h': 0.03332016,
#   'price_change_percentage_24h': 2.1268,
#   'market_cap_change_24h': 218059621,
#   'market_cap_change_percentage_24h': 2.19283,
#   'circulating_supply': 6351423586.62387,
#   'total_supply': 6800038050.38397,
#   'max_supply': 10000000000.0,
#   'ath': 3.56,
#   'ath_change_percentage': -54.88121,
#   'ath_date': '2019-06-20T14:51:19.480Z',
#   'atl': 0.105336,
#   'atl_change_percentage': 1425.36372,
#   'atl_date': '2020-03-13T02:20:48.438Z',
#   'roi': {'times': -0.33333289814737377,
#    'currency': 'usd',
#    'percentage': -33.33328981473738},
#   'last_updated': '2021-12-26T05:50:10.030Z'},
#  {'id': 'chainlink',
#   'symbol': 'link',
#   'name': 'Chainlink',
#   'image': 'https://assets.coingecko.com/coins/images/877/large/chainlink-new-logo.png?1547034700',
#   'current_price': 21.37,
#   'market_cap': 9987309335,
#   'market_cap_rank': 20,
#   'fully_diluted_valuation': 21385664009,
#   'total_volume': 647827617,
#   'high_24h': 22.38,
#   'low_24h': 21.22,
#   'price_change_24h': -0.230627285819,
#   'price_change_percentage_24h': -1.0676,
#   'market_cap_change_24h': -100876934.82671738,
#   'market_cap_change_percentage_24h': -0.99995,
#   'circulating_supply': 467009550.4397637,
#   'total_supply': 1000000000.0,
#   'max_supply': 1000000000.0,
#   'ath': 52.7,
#   'ath_change_percentage': -59.40212,
#   'ath_date': '2021-05-10T00:13:57.214Z',
#   'atl': 0.148183,
#   'atl_change_percentage': 14337.33521,
#   'atl_date': '2017-11-29T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2021-12-26T05:50:26.925Z'},
#  {'id': 'terrausd',
#   'symbol': 'ust',
#   'name': 'TerraUSD',
#   'image': 'https://assets.coingecko.com/coins/images/12681/large/UST.png?1601612407',
#   'current_price': 1.0,
#   'market_cap': 9915130463,
#   'market_cap_rank': 21,
#   'fully_diluted_valuation': None,
#   'total_volume': 173782773,
#   'high_24h': 1.01,
#   'low_24h': 0.997166,
#   'price_change_24h': -0.000757964796,
#   'price_change_percentage_24h': -0.07558,
#   'market_cap_change_24h': 77260659,
#   'market_cap_change_percentage_24h': 0.78534,
#   'circulating_supply': 9884589332.19778,
#   'total_supply': 9884704208.36954,
#   'max_supply': None,
#   'ath': 1.09,
#   'ath_change_percentage': -8.13341,
#   'ath_date': '2021-01-11T22:30:57.984Z',
#   'atl': 0.857992,
#   'atl_change_percentage': 16.91223,
#   'atl_date': '2021-05-19T13:14:26.898Z',
#   'roi': None,
#   'last_updated': '2021-12-26T05:48:38.137Z'},
#  {'id': 'dai',
#   'symbol': 'dai',
#   'name': 'Dai',
#   'image': 'https://assets.coingecko.com/coins/images/9956/large/4943.png?1636636734',
#   'current_price': 1.0,
#   'market_cap': 9053566228,
#   'market_cap_rank': 22,
#   'fully_diluted_valuation': 9053566228,
#   'total_volume': 296283547,
#   'high_24h': 1.01,
#   'low_24h': 0.994736,
#   'price_change_24h': 0.0018265,
#   'price_change_percentage_24h': 0.18255,
#   'market_cap_change_24h': 52114570,
#   'market_cap_change_percentage_24h': 0.57896,
#   'circulating_supply': 9032280285.4511,
#   'total_supply': 9032280285.4511,
#   'max_supply': 9032280285.4511,
#   'ath': 1.22,
#   'ath_change_percentage': -17.75156,
#   'ath_date': '2020-03-13T03:02:50.373Z',
#   'atl': 0.903243,
#   'atl_change_percentage': 10.99462,
#   'atl_date': '2019-11-25T00:04:18.137Z',
#   'roi': None,
#   'last_updated': '2021-12-26T05:47:58.949Z'},
#  {'id': 'near',
#   'symbol': 'near',
#   'name': 'Near',
#   'image': 'https://assets.coingecko.com/coins/images/10365/large/near_icon.png?1601359077',
#   'current_price': 14.77,
#   'market_cap': 8827110186,
#   'market_cap_rank': 23,
#   'fully_diluted_valuation': 14772227232,
#   'total_volume': 574639395,
#   'high_24h': 15.5,
#   'low_24h': 14.3,
#   'price_change_24h': 0.299766,
#   'price_change_percentage_24h': 2.07129,
#   'market_cap_change_24h': 183274428,
#   'market_cap_change_percentage_24h': 2.12029,
#   'circulating_supply': 597547685.104648,
#   'total_supply': 1000000000.0,
#   'max_supply': 1000000000.0,
#   'ath': 15.82,
#   'ath_change_percentage': -6.12835,
#   'ath_date': '2021-12-24T16:39:52.606Z',
#   'atl': 0.526762,
#   'atl_change_percentage': 2719.37043,
#   'atl_date': '2020-11-04T16:09:15.137Z',
#   'roi': None,
#   'last_updated': '2021-12-26T05:49:24.908Z'},
#  {'id': 'bitcoin-cash',
#   'symbol': 'bch',
#   'name': 'Bitcoin Cash',
#   'image': 'https://assets.coingecko.com/coins/images/780/large/bitcoin-cash-circle.png?1594689492',
#   'current_price': 448.94,
#   'market_cap': 8504931695,
#   'market_cap_rank': 24,
#   'fully_diluted_valuation': 9431114946,
#   'total_volume': 1805956347,
#   'high_24h': 460.12,
#   'low_24h': 447.07,
#   'price_change_24h': -4.067865368298,
#   'price_change_percentage_24h': -0.89796,
#   'market_cap_change_24h': -74005347.98849297,
#   'market_cap_change_percentage_24h': -0.86264,
#   'circulating_supply': 18937693.6466526,
#   'total_supply': 21000000.0,
#   'max_supply': 21000000.0,
#   'ath': 3785.82,
#   'ath_change_percentage': -88.13188,
#   'ath_date': '2017-12-20T00:00:00.000Z',
#   'atl': 76.93,
#   'atl_change_percentage': 484.00836,
#   'atl_date': '2018-12-16T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2021-12-26T05:50:40.060Z'},
#  {'id': 'cosmos',
#   'symbol': 'atom',
#   'name': 'Cosmos',
#   'image': 'https://assets.coingecko.com/coins/images/1481/large/cosmos_hub.png?1555657960',
#   'current_price': 29.46,
#   'market_cap': 8366090120,
#   'market_cap_rank': 25,
#   'fully_diluted_valuation': None,
#   'total_volume': 525594049,
#   'high_24h': 29.95,
#   'low_24h': 26.77,
#   'price_change_24h': 2.55,
#   'price_change_percentage_24h': 9.46135,
#   'market_cap_change_24h': 702914181,
#   'market_cap_change_percentage_24h': 9.17262,
#   'circulating_supply': 284012627.316362,
#   'total_supply': None,
#   'max_supply': None,
#   'ath': 44.42,
#   'ath_change_percentage': -33.52802,
#   'ath_date': '2021-09-20T00:05:25.062Z',
#   'atl': 1.16,
#   'atl_change_percentage': 2445.27556,
#   'atl_date': '2020-03-13T02:27:44.591Z',
#   'roi': {'times': 293.5675408571534,
#    'currency': 'usd',
#    'percentage': 29356.75408571534},
#   'last_updated': '2021-12-26T05:48:47.424Z'},
#  {'id': 'tron',
#   'symbol': 'trx',
#   'name': 'TRON',
#   'image': 'https://assets.coingecko.com/coins/images/1094/large/tron-logo.png?1547035066',
#   'current_price': 0.080396,
#   'market_cap': 8189441028,
#   'market_cap_rank': 26,
#   'fully_diluted_valuation': None,
#   'total_volume': 1128030757,
#   'high_24h': 0.082823,
#   'low_24h': 0.080163,
#   'price_change_24h': -0.000707376973,
#   'price_change_percentage_24h': -0.8722,
#   'market_cap_change_24h': -73745518.533741,
#   'market_cap_change_percentage_24h': -0.89246,
#   'circulating_supply': 101864246013.729,
#   'total_supply': 101900409184.273,
#   'max_supply': None,
#   'ath': 0.231673,
#   'ath_change_percentage': -65.27274,
#   'ath_date': '2018-01-05T00:00:00.000Z',
#   'atl': 0.00180434,
#   'atl_change_percentage': 4358.8891,
#   'atl_date': '2017-11-12T00:00:00.000Z',
#   'roi': {'times': 41.3134935822514,
#    'currency': 'usd',
#    'percentage': 4131.34935822514},
#   'last_updated': '2021-12-26T05:49:41.920Z'},
#  {'id': 'okb',
#   'symbol': 'okb',
#   'name': 'OKB',
#   'image': 'https://assets.coingecko.com/coins/images/4463/large/okb_token.png?1548386209',
#   'current_price': 29.93,
#   'market_cap': 7861641589,
#   'market_cap_rank': 27,
#   'fully_diluted_valuation': None,
#   'total_volume': 418636816,
#   'high_24h': 30.2,
#   'low_24h': 29.47,
#   'price_change_24h': -0.043259353968,
#   'price_change_percentage_24h': -0.14433,
#   'market_cap_change_24h': -17821639.153042793,
#   'market_cap_change_percentage_24h': -0.22618,
#   'circulating_supply': 262680011.32,
#   'total_supply': 300000000.0,
#   'max_supply': None,
#   'ath': 44.01,
#   'ath_change_percentage': -32.05776,
#   'ath_date': '2021-05-03T01:03:16.108Z',
#   'atl': 0.580608,
#   'atl_change_percentage': 5049.46212,
#   'atl_date': '2019-01-14T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2021-12-26T05:50:18.904Z'},
#  {'id': 'uniswap',
#   'symbol': 'uni',
#   'name': 'Uniswap',
#   'image': 'https://assets.coingecko.com/coins/images/12504/large/uniswap-uni.png?1600306604',
#   'current_price': 16.82,
#   'market_cap': 7653506359,
#   'market_cap_rank': 28,
#   'fully_diluted_valuation': 16874760281,
#   'total_volume': 205956564,
#   'high_24h': 17.72,
#   'low_24h': 16.86,
#   'price_change_24h': -0.798775673461,
#   'price_change_percentage_24h': -4.53332,
#   'market_cap_change_24h': -326606157.8988867,
#   'market_cap_change_percentage_24h': -4.09275,
#   'circulating_supply': 453547560.48836,
#   'total_supply': 1000000000.0,
#   'max_supply': 1000000000.0,
#   'ath': 44.92,
#   'ath_change_percentage': -62.45911,
#   'ath_date': '2021-05-03T05:25:04.822Z',
#   'atl': 1.03,
#   'atl_change_percentage': 1536.87798,
#   'atl_date': '2020-09-17T01:20:38.214Z',
#   'roi': None,
#   'last_updated': '2021-12-26T05:48:10.780Z'},
#  {'id': 'axie-infinity',
#   'symbol': 'axs',
#   'name': 'Axie Infinity',
#   'image': 'https://assets.coingecko.com/coins/images/13029/large/axie_infinity_logo.png?1604471082',
#   'current_price': 106.24,
#   'market_cap': 7219004120,
#   'market_cap_rank': 29,
#   'fully_diluted_valuation': 28712286050,
#   'total_volume': 276058503,
#   'high_24h': 110.34,
#   'low_24h': 105.57,
#   'price_change_24h': -0.359708515704,
#   'price_change_percentage_24h': -0.33744,
#   'market_cap_change_24h': 3186893,
#   'market_cap_change_percentage_24h': 0.04417,
#   'circulating_supply': 67884915.50412226,
#   'total_supply': 270000000.0,
#   'max_supply': 270000000.0,
#   'ath': 164.9,
#   'ath_change_percentage': -35.51478,
#   'ath_date': '2021-11-06T19:29:29.482Z',
#   'atl': 0.123718,
#   'atl_change_percentage': 85849.12202,
#   'atl_date': '2020-11-06T08:05:43.662Z',
#   'roi': None,
#   'last_updated': '2021-12-26T05:48:47.740Z'},
#  {'id': 'stellar',
#   'symbol': 'xlm',
#   'name': 'Stellar',
#   'image': 'https://assets.coingecko.com/coins/images/100/large/Stellar_symbol_black_RGB.png?1552356157',
#   'current_price': 0.287834,
#   'market_cap': 7121709509,
#   'market_cap_rank': 30,
#   'fully_diluted_valuation': 14402118228,
#   'total_volume': 294576621,
#   'high_24h': 0.295144,
#   'low_24h': 0.286341,
#   'price_change_24h': -0.001798329865,
#   'price_change_percentage_24h': -0.6209,
#   'market_cap_change_24h': -37319013.78889465,
#   'market_cap_change_percentage_24h': -0.52129,
#   'circulating_supply': 24725412341.0886,
#   'total_supply': 50001802422.1399,
#   'max_supply': 50001802422.1399,
#   'ath': 0.875563,
#   'ath_change_percentage': -67.09797,
#   'ath_date': '2018-01-03T00:00:00.000Z',
#   'atl': 0.00047612,
#   'atl_change_percentage': 60404.9073,
#   'atl_date': '2015-03-05T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2021-12-26T05:50:55.899Z'},
#  {'id': 'staked-ether',
#   'symbol': 'steth',
#   'name': 'Lido Staked Ether',
#   'image': 'https://assets.coingecko.com/coins/images/13442/large/steth_logo.png?1608607546',
#   'current_price': 4009.24,
#   'market_cap': 6495829636,
#   'market_cap_rank': 31,
#   'fully_diluted_valuation': 6495791349,
#   'total_volume': 7658747,
#   'high_24h': 4102.89,
#   'low_24h': 4002.02,
#   'price_change_24h': -10.512628961768,
#   'price_change_percentage_24h': -0.26152,
#   'market_cap_change_24h': 3423151,
#   'market_cap_change_percentage_24h': 0.05273,
#   'circulating_supply': 1618064.08622231,
#   'total_supply': 1618064.08622231,
#   'max_supply': 1618064.08622231,
#   'ath': 4829.57,
#   'ath_change_percentage': -16.87521,
#   'ath_date': '2021-11-10T14:40:47.256Z',
#   'atl': 482.9,
#   'atl_change_percentage': 731.3526,
#   'atl_date': '2020-12-22T04:08:21.854Z',
#   'roi': None,
#   'last_updated': '2021-12-26T05:49:53.098Z'},
#  {'id': 'the-sandbox',
#   'symbol': 'sand',
#   'name': 'The Sandbox',
#   'image': 'https://assets.coingecko.com/coins/images/12129/large/sandbox_logo.jpg?1597397942',
#   'current_price': 6.82,
#   'market_cap': 6266980093,
#   'market_cap_rank': 32,
#   'fully_diluted_valuation': 20446954482,
#   'total_volume': 2504639130,
#   'high_24h': 7.01,
#   'low_24h': 6.07,
#   'price_change_24h': 0.748997,
#   'price_change_percentage_24h': 12.34613,
#   'market_cap_change_24h': 698385726,
#   'market_cap_change_percentage_24h': 12.54151,
#   'circulating_supply': 919498319.2233225,
#   'total_supply': 3000000000.0,
#   'max_supply': 3000000000.0,
#   'ath': 8.4,
#   'ath_change_percentage': -18.55311,
#   'ath_date': '2021-11-25T06:04:40.957Z',
#   'atl': 0.02897764,
#   'atl_change_percentage': 23500.70963,
#   'atl_date': '2020-11-04T15:59:14.441Z',
#   'roi': None,
#   'last_updated': '2021-12-26T05:50:10.005Z'},
#  {'id': 'vechain',
#   'symbol': 'vet',
#   'name': 'VeChain',
#   'image': 'https://assets.coingecko.com/coins/images/1167/large/VeChain-Logo-768x725.png?1547035194',
#   'current_price': 0.09251,
#   'market_cap': 6176028517,
#   'market_cap_rank': 33,
#   'fully_diluted_valuation': None,
#   'total_volume': 232392414,
#   'high_24h': 0.095488,
#   'low_24h': 0.092113,
#   'price_change_24h': -0.000968108959,
#   'price_change_percentage_24h': -1.03565,
#   'market_cap_change_24h': -54616692.87641716,
#   'market_cap_change_percentage_24h': -0.87658,
#   'circulating_supply': 66760741299.0,
#   'total_supply': 86712634466.0,
#   'max_supply': None,
#   'ath': 0.280991,
#   'ath_change_percentage': -67.0243,
#   'ath_date': '2021-04-19T01:08:21.675Z',
#   'atl': 0.00191713,
#   'atl_change_percentage': 4733.19452,
#   'atl_date': '2020-03-13T02:29:59.652Z',
#   'roi': {'times': 7.023124809479582,
#    'currency': 'eth',
#    'percentage': 702.3124809479582},
#   'last_updated': '2021-12-26T05:49:43.813Z'},
#  {'id': 'compound-ether',
#   'symbol': 'ceth',
#   'name': 'cETH',
#   'image': 'https://assets.coingecko.com/coins/images/10643/large/ceth2.JPG?1581389598',
#   'current_price': 80.95,
#   'market_cap': 5968023963,
#   'market_cap_rank': 34,
#   'fully_diluted_valuation': None,
#   'total_volume': 1241471,
#   'high_24h': 83.08,
#   'low_24h': 76.88,
#   'price_change_24h': -0.39223935364,
#   'price_change_percentage_24h': -0.48223,
#   'market_cap_change_24h': -27912113.235607147,
#   'market_cap_change_percentage_24h': -0.46552,
#   'circulating_supply': 73728697.4425022,
#   'total_supply': 73728697.4425022,
#   'max_supply': None,
#   'ath': 97.75,
#   'ath_change_percentage': -17.19212,
#   'ath_date': '2021-11-21T12:39:57.508Z',
#   'atl': 1.89,
#   'atl_change_percentage': 4191.24066,
#   'atl_date': '2020-03-13T02:22:33.711Z',
#   'roi': None,
#   'last_updated': '2021-12-26T05:48:11.140Z'},
#  {'id': 'ftx-token',
#   'symbol': 'ftt',
#   'name': 'FTX Token',
#   'image': 'https://assets.coingecko.com/coins/images/9026/large/F.png?1609051564',
#   'current_price': 42.24,
#   'market_cap': 5871195676,
#   'market_cap_rank': 35,
#   'fully_diluted_valuation': 14144558551,
#   'total_volume': 46197859,
#   'high_24h': 43.3,
#   'low_24h': 42.07,
#   'price_change_24h': -0.794749482561,
#   'price_change_percentage_24h': -1.8468,
#   'market_cap_change_24h': -110555736.57741165,
#   'market_cap_change_percentage_24h': -1.84822,
#   'circulating_supply': 138998762.21874323,
#   'total_supply': 334868098.285971,
#   'max_supply': 334868098.285971,
#   'ath': 84.18,
#   'ath_change_percentage': -49.75832,
#   'ath_date': '2021-09-09T16:59:43.151Z',
#   'atl': 1.15,
#   'atl_change_percentage': 3578.70008,
#   'atl_date': '2019-09-06T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2021-12-26T05:50:05.091Z'},
#  {'id': 'hedera-hashgraph',
#   'symbol': 'hbar',
#   'name': 'Hedera',
#   'image': 'https://assets.coingecko.com/coins/images/3688/large/hbar.png?1637045634',
#   'current_price': 0.308237,
#   'market_cap': 5695015508,
#   'market_cap_rank': 36,
#   'fully_diluted_valuation': None,
#   'total_volume': 55833512,
#   'high_24h': 0.320613,
#   'low_24h': 0.306213,
#   'price_change_24h': -0.005027011205,
#   'price_change_percentage_24h': -1.60472,
#   'market_cap_change_24h': -89943675.53485107,
#   'market_cap_change_percentage_24h': -1.55478,
#   'circulating_supply': 18476107922.0,
#   'total_supply': 50000000000.0,
#   'max_supply': None,
#   'ath': 0.569229,
#   'ath_change_percentage': -45.80452,
#   'ath_date': '2021-09-15T10:40:28.318Z',
#   'atl': 0.00986111,
#   'atl_change_percentage': 3028.41383,
#   'atl_date': '2020-01-02T17:30:24.852Z',
#   'roi': None,
#   'last_updated': '2021-12-26T05:49:35.944Z'},
#  {'id': 'fantom',
#   'symbol': 'ftm',
#   'name': 'Fantom',
#   'image': 'https://assets.coingecko.com/coins/images/4001/large/Fantom.png?1558015016',
#   'current_price': 2.19,
#   'market_cap': 5561098728,
#   'market_cap_rank': 37,
#   'fully_diluted_valuation': 6948220092,
#   'total_volume': 740369444,
#   'high_24h': 2.24,
#   'low_24h': 2.0,
#   'price_change_24h': 0.04771295,
#   'price_change_percentage_24h': 2.22885,
#   'market_cap_change_24h': 121245891,
#   'market_cap_change_percentage_24h': 2.22885,
#   'circulating_supply': 2541152731.01,
#   'total_supply': 3175000000.0,
#   'max_supply': 3175000000.0,
#   'ath': 3.46,
#   'ath_change_percentage': -36.41398,
#   'ath_date': '2021-10-28T05:19:39.845Z',
#   'atl': 0.00190227,
#   'atl_change_percentage': 115507.65522,
#   'atl_date': '2020-03-13T02:25:38.280Z',
#   'roi': {'times': 71.9471925632863,
#    'currency': 'usd',
#    'percentage': 7194.71925632863},
#   'last_updated': '2021-12-26T05:49:21.243Z'},
#  {'id': 'theta-token',
#   'symbol': 'theta',
#   'name': 'Theta Network',
#   'image': 'https://assets.coingecko.com/coins/images/2538/large/theta-token-logo.png?1548387191',
#   'current_price': 5.11,
#   'market_cap': 5114781696,
#   'market_cap_rank': 38,
#   'fully_diluted_valuation': None,
#   'total_volume': 262408124,
#   'high_24h': 5.21,
#   'low_24h': 4.86,
#   'price_change_24h': 0.201055,
#   'price_change_percentage_24h': 4.09169,
#   'market_cap_change_24h': 213969670,
#   'market_cap_change_percentage_24h': 4.366,
#   'circulating_supply': 1000000000.0,
#   'total_supply': 1000000000.0,
#   'max_supply': None,
#   'ath': 15.72,
#   'ath_change_percentage': -67.43619,
#   'ath_date': '2021-04-16T13:15:11.190Z',
#   'atl': 0.04039979,
#   'atl_change_percentage': 12570.70433,
#   'atl_date': '2020-03-13T02:24:16.483Z',
#   'roi': {'times': 33.09854463975614,
#    'currency': 'usd',
#    'percentage': 3309.854463975614},
#   'last_updated': '2021-12-26T05:49:39.892Z'},
#  {'id': 'internet-computer',
#   'symbol': 'icp',
#   'name': 'Internet Computer',
#   'image': 'https://assets.coingecko.com/coins/images/14495/large/Internet_Computer_logo.png?1620703073',
#   'current_price': 26.62,
#   'market_cap': 5093327582,
#   'market_cap_rank': 39,
#   'fully_diluted_valuation': 12525176546,
#   'total_volume': 198079286,
#   'high_24h': 27.83,
#   'low_24h': 26.3,
#   'price_change_24h': -0.816326568838,
#   'price_change_percentage_24h': -2.97528,
#   'market_cap_change_24h': -160333899.6255951,
#   'market_cap_change_percentage_24h': -3.05185,
#   'circulating_supply': 190804426.75,
#   'total_supply': 469213710.0,
#   'max_supply': 469213710.0,
#   'ath': 700.65,
#   'ath_change_percentage': -96.19009,
#   'ath_date': '2021-05-10T16:05:53.653Z',
#   'atl': 21.04,
#   'atl_change_percentage': 26.86177,
#   'atl_date': '2021-12-20T12:59:41.703Z',
#   'roi': None,
#   'last_updated': '2021-12-26T05:49:55.007Z'},
#  {'id': 'filecoin',
#   'symbol': 'fil',
#   'name': 'Filecoin',
#   'image': 'https://assets.coingecko.com/coins/images/12817/large/filecoin.png?1602753933',
#   'current_price': 35.88,
#   'market_cap': 5092883654,
#   'market_cap_rank': 40,
#   'fully_diluted_valuation': 70754554123,
#   'total_volume': 372630974,
#   'high_24h': 37.33,
#   'low_24h': 35.66,
#   'price_change_24h': -0.618949626751,
#   'price_change_percentage_24h': -1.69597,
#   'market_cap_change_24h': -62516719.77448654,
#   'market_cap_change_percentage_24h': -1.21265,
#   'circulating_supply': 141866106.0,
#   'total_supply': 1970921340.0,
#   'max_supply': 1970921340.0,
#   'ath': 236.84,
#   'ath_change_percentage': -84.83752,
#   'ath_date': '2021-04-01T13:29:41.564Z',
#   'atl': 20.06,
#   'atl_change_percentage': 79.02092,
#   'atl_date': '2020-12-29T22:32:28.483Z',
#   'roi': None,
#   'last_updated': '2021-12-26T05:50:06.022Z'},
#  {'id': 'elrond-erd-2',
#   'symbol': 'egld',
#   'name': 'Elrond',
#   'image': 'https://assets.coingecko.com/coins/images/12335/large/elrond3_360.png?1626341589',
#   'current_price': 248.01,
#   'market_cap': 5027461954,
#   'market_cap_rank': 41,
#   'fully_diluted_valuation': None,
#   'total_volume': 94476107,
#   'high_24h': 259.9,
#   'low_24h': 245.66,
#   'price_change_24h': -7.03423710237,
#   'price_change_percentage_24h': -2.75809,
#   'market_cap_change_24h': -140947863.99980545,
#   'market_cap_change_percentage_24h': -2.7271,
#   'circulating_supply': 20277925.0,
#   'total_supply': 20397843.0,
#   'max_supply': None,
#   'ath': 545.64,
#   'ath_change_percentage': -54.56367,
#   'ath_date': '2021-11-23T10:33:26.737Z',
#   'atl': 6.51,
#   'atl_change_percentage': 3710.22662,
#   'atl_date': '2020-10-07T01:44:53.554Z',
#   'roi': None,
#   'last_updated': '2021-12-26T05:48:41.186Z'},
#  {'id': 'decentraland',
#   'symbol': 'mana',
#   'name': 'Decentraland',
#   'image': 'https://assets.coingecko.com/coins/images/878/large/decentraland-mana.png?1550108745',
#   'current_price': 3.71,
#   'market_cap': 4929292173,
#   'market_cap_rank': 43,
#   'fully_diluted_valuation': 8147261644,
#   'total_volume': 927008510,
#   'high_24h': 3.83,
#   'low_24h': 3.62,
#   'price_change_24h': 0.091821,
#   'price_change_percentage_24h': 2.53858,
#   'market_cap_change_24h': 129641340,
#   'market_cap_change_percentage_24h': 2.70106,
#   'circulating_supply': 1327372145.9864838,
#   'total_supply': 2193915027.32015,
#   'max_supply': 2193915027.32015,
#   'ath': 5.85,
#   'ath_change_percentage': -36.62081,
#   'ath_date': '2021-11-25T10:04:18.534Z',
#   'atl': 0.00923681,
#   'atl_change_percentage': 40045.93233,
#   'atl_date': '2017-10-31T00:00:00.000Z',
#   'roi': {'times': 184.44203453481694,
#    'currency': 'usd',
#    'percentage': 18444.203453481696},
#   'last_updated': '2021-12-26T05:50:20.516Z'},
#  {'id': 'ethereum-classic',
#   'symbol': 'etc',
#   'name': 'Ethereum Classic',
#   'image': 'https://assets.coingecko.com/coins/images/453/large/ethereum-classic-logo.png?1547034169',
#   'current_price': 37.36,
#   'market_cap': 4927644587,
#   'market_cap_rank': 42,
#   'fully_diluted_valuation': 7872672530,
#   'total_volume': 295324369,
#   'high_24h': 38.79,
#   'low_24h': 37.26,
#   'price_change_24h': -0.650591445831,
#   'price_change_percentage_24h': -1.71141,
#   'market_cap_change_24h': -84230227.2316904,
#   'market_cap_change_percentage_24h': -1.68061,
#   'circulating_supply': 131880846.131576,
#   'total_supply': 210700000.0,
#   'max_supply': 210700000.0,
#   'ath': 167.09,
#   'ath_change_percentage': -77.61923,
#   'ath_date': '2021-05-06T18:34:22.133Z',
#   'atl': 0.615038,
#   'atl_change_percentage': 5980.11077,
#   'atl_date': '2016-07-25T00:00:00.000Z',
#   'roi': {'times': 82.03193091442407,
#    'currency': 'usd',
#    'percentage': 8203.193091442407},
#   'last_updated': '2021-12-26T05:48:17.338Z'},
#  {'id': 'magic-internet-money',
#   'symbol': 'mim',
#   'name': 'Magic Internet Money',
#   'image': 'https://assets.coingecko.com/coins/images/16786/large/mimlogopng.png?1624979612',
#   'current_price': 1.0,
#   'market_cap': 4545138625,
#   'market_cap_rank': 44,
#   'fully_diluted_valuation': None,
#   'total_volume': 221040613,
#   'high_24h': 1.02,
#   'low_24h': 0.993619,
#   'price_change_24h': 0.00146967,
#   'price_change_percentage_24h': 0.14648,
#   'market_cap_change_24h': 10749507,
#   'market_cap_change_percentage_24h': 0.23707,
#   'circulating_supply': 4519748141.24997,
#   'total_supply': 4519748141.24997,
#   'max_supply': None,
#   'ath': 1.04,
#   'ath_change_percentage': -3.41365,
#   'ath_date': '2021-10-06T13:25:17.751Z',
#   'atl': 0.919196,
#   'atl_change_percentage': 9.39092,
#   'atl_date': '2021-12-04T05:29:56.806Z',
#   'roi': None,
#   'last_updated': '2021-12-26T05:48:53.550Z'},
#  {'id': 'cdai',
#   'symbol': 'cdai',
#   'name': 'cDAI',
#   'image': 'https://assets.coingecko.com/coins/images/9281/large/cDAI.png?1576467585',
#   'current_price': 0.02182184,
#   'market_cap': 4277550743,
#   'market_cap_rank': 45,
#   'fully_diluted_valuation': None,
#   'total_volume': 35435449,
#   'high_24h': 0.02207287,
#   'low_24h': 0.02167124,
#   'price_change_24h': 6.14e-06,
#   'price_change_percentage_24h': 0.02815,
#   'market_cap_change_24h': 36398934,
#   'market_cap_change_percentage_24h': 0.85823,
#   'circulating_supply': 196021536727.559,
#   'total_supply': 196021536727.559,
#   'max_supply': None,
#   'ath': 0.03159087,
#   'ath_change_percentage': -30.89337,
#   'ath_date': '2020-10-12T21:29:00.007Z',
#   'atl': 0.00728854,
#   'atl_change_percentage': 199.53009,
#   'atl_date': '2020-03-18T04:29:40.819Z',
#   'roi': None,
#   'last_updated': '2021-12-26T05:48:07.517Z'},
#  {'id': 'tezos',
#   'symbol': 'xtz',
#   'name': 'Tezos',
#   'image': 'https://assets.coingecko.com/coins/images/976/large/Tezos-logo.png?1547034862',
#   'current_price': 4.55,
#   'market_cap': 3963630649,
#   'market_cap_rank': 46,
#   'fully_diluted_valuation': None,
#   'total_volume': 156113254,
#   'high_24h': 4.68,
#   'low_24h': 4.49,
#   'price_change_24h': -0.082619618204,
#   'price_change_percentage_24h': -1.78336,
#   'market_cap_change_24h': -63816998.28568792,
#   'market_cap_change_percentage_24h': -1.58455,
#   'circulating_supply': 871091679.70972,
#   'total_supply': None,
#   'max_supply': None,
#   'ath': 9.12,
#   'ath_change_percentage': -50.30815,
#   'ath_date': '2021-10-04T00:41:18.025Z',
#   'atl': 0.350476,
#   'atl_change_percentage': 1192.51107,
#   'atl_date': '2018-12-07T00:00:00.000Z',
#   'roi': {'times': 8.68125043168748,
#    'currency': 'usd',
#    'percentage': 868.1250431687481},
#   'last_updated': '2021-12-26T05:50:11.151Z'},
#  {'id': 'monero',
#   'symbol': 'xmr',
#   'name': 'Monero',
#   'image': 'https://assets.coingecko.com/coins/images/69/large/monero_logo.png?1547033729',
#   'current_price': 208.27,
#   'market_cap': 3761788275,
#   'market_cap_rank': 47,
#   'fully_diluted_valuation': None,
#   'total_volume': 141093459,
#   'high_24h': 216.68,
#   'low_24h': 206.91,
#   'price_change_24h': -0.619293827244,
#   'price_change_percentage_24h': -0.29646,
#   'market_cap_change_24h': -7495507.382441521,
#   'market_cap_change_percentage_24h': -0.19886,
#   'circulating_supply': 18052402.4599074,
#   'total_supply': None,
#   'max_supply': None,
#   'ath': 542.33,
#   'ath_change_percentage': -61.53067,
#   'ath_date': '2018-01-09T00:00:00.000Z',
#   'atl': 0.216177,
#   'atl_change_percentage': 96408.55201,
#   'atl_date': '2015-01-14T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2021-12-26T05:50:21.854Z'},
#  {'id': 'gala',
#   'symbol': 'gala',
#   'name': 'Gala',
#   'image': 'https://assets.coingecko.com/coins/images/12493/large/GALA-COINGECKO.png?1600233435',
#   'current_price': 0.49264,
#   'market_cap': 3720576588,
#   'market_cap_rank': 48,
#   'fully_diluted_valuation': 24664092006,
#   'total_volume': 556932623,
#   'high_24h': 0.510636,
#   'low_24h': 0.483607,
#   'price_change_24h': 0.00662753,
#   'price_change_percentage_24h': 1.36365,
#   'market_cap_change_24h': 23652382,
#   'market_cap_change_percentage_24h': 0.63979,
#   'circulating_supply': 7542496572.319239,
#   'total_supply': 36428416242.4451,
#   'max_supply': 50000000000.0,
#   'ath': 0.824837,
#   'ath_change_percentage': -40.19641,
#   'ath_date': '2021-11-26T01:03:48.731Z',
#   'atl': 0.00013475,
#   'atl_change_percentage': 365973.68981,
#   'atl_date': '2020-12-28T08:46:48.367Z',
#   'roi': None,
#   'last_updated': '2021-12-26T05:49:07.949Z'},
#  {'id': 'helium',
#   'symbol': 'hnt',
#   'name': 'Helium',
#   'image': 'https://assets.coingecko.com/coins/images/4284/large/Helium_HNT.png?1612620071',
#   'current_price': 36.71,
#   'market_cap': 3690751998,
#   'market_cap_rank': 49,
#   'fully_diluted_valuation': 8186223578,
#   'total_volume': 14719769,
#   'high_24h': 38.74,
#   'low_24h': 36.27,
#   'price_change_24h': -1.749521879856,
#   'price_change_percentage_24h': -4.54905,
#   'market_cap_change_24h': -175895813.57826853,
#   'market_cap_change_percentage_24h': -4.54905,
#   'circulating_supply': 100539361.984279,
#   'total_supply': 223000000.0,
#   'max_supply': 223000000.0,
#   'ath': 54.88,
#   'ath_change_percentage': -33.11335,
#   'ath_date': '2021-11-12T23:08:25.301Z',
#   'atl': 0.113248,
#   'atl_change_percentage': 32311.6345,
#   'atl_date': '2020-04-18T00:19:10.902Z',
#   'roi': None,
#   'last_updated': '2021-12-26T05:48:27.360Z'},
#  {'id': 'the-graph',
#   'symbol': 'grt',
#   'name': 'The Graph',
#   'image': 'https://assets.coingecko.com/coins/images/13397/large/Graph_Token.png?1608145566',
#   'current_price': 0.701628,
#   'market_cap': 3687340321,
#   'market_cap_rank': 50,
#   'fully_diluted_valuation': 7018369225,
#   'total_volume': 91777019,
#   'high_24h': 0.728367,
#   'low_24h': 0.689607,
#   'price_change_24h': -0.000339562316,
#   'price_change_percentage_24h': -0.04837,
#   'market_cap_change_24h': -10246393.642324924,
#   'market_cap_change_percentage_24h': -0.27711,
#   'circulating_supply': 5253842029.0,
#   'total_supply': 10000000000.0,
#   'max_supply': 10000000000.0,
#   'ath': 2.84,
#   'ath_change_percentage': -75.29035,
#   'ath_date': '2021-02-12T07:28:45.775Z',
#   'atl': 0.103254,
#   'atl_change_percentage': 579.99666,
#   'atl_date': '2020-12-17T21:28:41.332Z',
#   'roi': None,
#   'last_updated': '2021-12-26T05:48:21.302Z'},
#  {'id': 'iota',
#   'symbol': 'miota',
#   'name': 'IOTA',
#   'image': 'https://assets.coingecko.com/coins/images/692/large/IOTA_Swirl.png?1604238557',
#   'current_price': 1.28,
#   'market_cap': 3569345808,
#   'market_cap_rank': 51,
#   'fully_diluted_valuation': None,
#   'total_volume': 61764166,
#   'high_24h': 1.35,
#   'low_24h': 1.28,
#   'price_change_24h': -0.056428558022,
#   'price_change_percentage_24h': -4.20926,
#   'market_cap_change_24h': -154565537.37677908,
#   'market_cap_change_percentage_24h': -4.15062,
#   'circulating_supply': 2779530283.277761,
#   'total_supply': 2779530283.0,
#   'max_supply': None,
#   'ath': 5.25,
#   'ath_change_percentage': -75.51137,
#   'ath_date': '2017-12-19T00:00:00.000Z',
#   'atl': 0.081637,
#   'atl_change_percentage': 1474.46775,
#   'atl_date': '2020-03-13T02:22:41.168Z',
#   'roi': {'times': 18.16262741961791,
#    'currency': 'btc',
#    'percentage': 1816.262741961791},
#   'last_updated': '2021-12-26T05:49:28.527Z'},
#  {'id': 'aave',
#   'symbol': 'aave',
#   'name': 'Aave',
#   'image': 'https://assets.coingecko.com/coins/images/12645/large/AAVE.png?1601374110',
#   'current_price': 253.08,
#   'market_cap': 3412013275,
#   'market_cap_rank': 52,
#   'fully_diluted_valuation': 4058509639,
#   'total_volume': 358577921,
#   'high_24h': 271.38,
#   'low_24h': 251.53,
#   'price_change_24h': -14.826504411952,
#   'price_change_percentage_24h': -5.5342,
#   'market_cap_change_24h': -185610562.2519331,
#   'market_cap_change_percentage_24h': -5.15925,
#   'circulating_supply': 13451295.490990933,
#   'total_supply': 16000000.0,
#   'max_supply': 16000000.0,
#   'ath': 661.69,
#   'ath_change_percentage': -61.66514,
#   'ath_date': '2021-05-18T21:19:59.514Z',
#   'atl': 26.02,
#   'atl_change_percentage': 874.73969,
#   'atl_date': '2020-11-05T09:20:11.928Z',
#   'roi': None,
#   'last_updated': '2021-12-26T05:50:35.099Z'},
#  {'id': 'klay-token',
#   'symbol': 'klay',
#   'name': 'Klaytn',
#   'image': 'https://assets.coingecko.com/coins/images/9672/large/CjbT82vP_400x400.jpg?1570548320',
#   'current_price': 1.33,
#   'market_cap': 3393845150,
#   'market_cap_rank': 53,
#   'fully_diluted_valuation': None,
#   'total_volume': 16686035,
#   'high_24h': 1.37,
#   'low_24h': 1.32,
#   'price_change_24h': 0.00374919,
#   'price_change_percentage_24h': 0.28322,
#   'market_cap_change_24h': 11743638,
#   'market_cap_change_percentage_24h': 0.34723,
#   'circulating_supply': 2556523947.0,
#   'total_supply': None,
#   'max_supply': None,
#   'ath': 4.34,
#   'ath_change_percentage': -69.37434,
#   'ath_date': '2021-03-30T03:44:28.828Z',
#   'atl': 0.06044,
#   'atl_change_percentage': 2098.59322,
#   'atl_date': '2020-04-29T08:19:34.574Z',
#   'roi': None,
#   'last_updated': '2021-12-26T05:50:06.247Z'},
#  {'id': 'compound-usd-coin',
#   'symbol': 'cusdc',
#   'name': 'cUSDC',
#   'image': 'https://assets.coingecko.com/coins/images/9442/large/Compound_USDC.png?1567581577',
#   'current_price': 0.02245768,
#   'market_cap': 3333442748,
#   'market_cap_rank': 54,
#   'fully_diluted_valuation': None,
#   'total_volume': 137852511,
#   'high_24h': 0.02270564,
#   'low_24h': 0.02228295,
#   'price_change_24h': 1.76e-06,
#   'price_change_percentage_24h': 0.00784,
#   'market_cap_change_24h': -49571448.57638407,
#   'market_cap_change_percentage_24h': -1.4653,
#   'circulating_supply': 148432213457.428,
#   'total_supply': 148432213457.428,
# ...
#   'high_24h': 23.41,
#   'low_24h': 22.53,
#   'price_change_24h': -0.393720275539,
#   'price_change_percentage_24h': -1.69458,
#   'market_cap_change_24h': -30269189.38681698,
#   'market_cap_change_percentage_24h': -1.69783,
#   'circulating_supply': 76729977.0,
#   'total_supply': 166729977.0,
#   'max_supply': None,
#   'ath': 28.83,
#   'ath_change_percentage': -20.81398,
#   'ath_date': '2021-12-01T15:09:35.541Z',
#   'atl': 0.342863,
#   'atl_change_percentage': 6558.41421,
#   'atl_date': '2019-02-07T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2021-12-26T05:49:14.400Z'},
#  {'id': 'celo',
#   'symbol': 'celo',
#   'name': 'Celo',
#   'image': 'https://assets.coingecko.com/coins/images/11090/large/icon-celo-CELO-color-500.png?1592293590',
#   'current_price': 4.77,
#   'market_cap': 1751184150,
#   'market_cap_rank': 84,
#   'fully_diluted_valuation': 4768961639,
#   'total_volume': 34607580,
#   'high_24h': 4.95,
#   'low_24h': 4.72,
#   'price_change_24h': -0.169856710846,
#   'price_change_percentage_24h': -3.43922,
#   'market_cap_change_24h': -61405386.04718804,
#   'market_cap_change_percentage_24h': -3.38772,
#   'circulating_supply': 367204495.0,
#   'total_supply': 1000000000.0,
#   'max_supply': 1000000000.0,
#   'ath': 9.82,
#   'ath_change_percentage': -51.46154,
#   'ath_date': '2021-08-30T14:25:09.929Z',
#   'atl': 0.800156,
#   'atl_change_percentage': 495.77265,
#   'atl_date': '2020-05-22T04:15:27.736Z',
#   'roi': None,
#   'last_updated': '2021-12-26T05:49:29.188Z'},
#  {'id': 'spell-token',
#   'symbol': 'spell',
#   'name': 'Spell Token',
#   'image': 'https://assets.coingecko.com/coins/images/15861/large/abracadabra-3.png?1622544862',
#   'current_price': 0.0220207,
#   'market_cap': 1735756148,
#   'market_cap_rank': 85,
#   'fully_diluted_valuation': 4628904414,
#   'total_volume': 59459602,
#   'high_24h': 0.02341997,
#   'low_24h': 0.02158907,
#   'price_change_24h': -0.001238692096,
#   'price_change_percentage_24h': -5.32556,
#   'market_cap_change_24h': -96238846.58112168,
#   'market_cap_change_percentage_24h': -5.25323,
#   'circulating_supply': 78746234207.8688,
#   'total_supply': 103214939480.85785,
#   'max_supply': 210000000000.0,
#   'ath': 0.03506357,
#   'ath_change_percentage': -37.13588,
#   'ath_date': '2021-11-02T08:44:42.429Z',
#   'atl': 0.00029812,
#   'atl_change_percentage': 7293.69467,
#   'atl_date': '2021-08-05T13:00:27.077Z',
#   'roi': None,
#   'last_updated': '2021-12-26T05:49:54.860Z'},
#  {'id': 'chiliz',
#   'symbol': 'chz',
#   'name': 'Chiliz',
#   'image': 'https://assets.coingecko.com/coins/images/8834/large/Chiliz.png?1561970540',
#   'current_price': 0.319202,
#   'market_cap': 1705835846,
#   'market_cap_rank': 86,
#   'fully_diluted_valuation': 2837350685,
#   'total_volume': 197669694,
#   'high_24h': 0.331059,
#   'low_24h': 0.306277,
#   'price_change_24h': 0.00801886,
#   'price_change_percentage_24h': 2.5769,
#   'market_cap_change_24h': 43653490,
#   'market_cap_change_percentage_24h': 2.62628,
#   'circulating_supply': 5344064580.0,
#   'total_supply': 8888888888.0,
#   'max_supply': 8888888888.0,
#   'ath': 0.878633,
#   'ath_change_percentage': -63.50973,
#   'ath_date': '2021-03-13T08:04:21.200Z',
#   'atl': 0.00410887,
#   'atl_change_percentage': 7703.00458,
#   'atl_date': '2019-09-28T00:00:00.000Z',
#   'roi': {'times': 13.509179639196105,
#    'currency': 'usd',
#    'percentage': 1350.9179639196104},
#   'last_updated': '2021-12-26T05:50:35.660Z'},
#  {'id': 'frax',
#   'symbol': 'frax',
#   'name': 'Frax',
#   'image': 'https://assets.coingecko.com/coins/images/13422/large/frax_logo.png?1608476506',
#   'current_price': 1.0,
#   'market_cap': 1626661897,
#   'market_cap_rank': 87,
#   'fully_diluted_valuation': 1626661897,
#   'total_volume': 10304837,
#   'high_24h': 1.01,
#   'low_24h': 0.9943,
#   'price_change_24h': -0.001878211997,
#   'price_change_percentage_24h': -0.1868,
#   'market_cap_change_24h': -265533.149364233,
#   'market_cap_change_percentage_24h': -0.01632,
#   'circulating_supply': 1620574681.90788,
#   'total_supply': 1620574681.90788,
#   'max_supply': 1620574681.90788,
#   'ath': 1.14,
#   'ath_change_percentage': -11.97648,
#   'ath_date': '2021-02-07T12:55:35.766Z',
#   'atl': 0.891635,
#   'atl_change_percentage': 12.58699,
#   'atl_date': '2021-12-04T05:33:57.315Z',
#   'roi': None,
#   'last_updated': '2021-12-26T05:49:08.996Z'},
#  {'id': 'celsius-degree-token',
#   'symbol': 'cel',
#   'name': 'Celsius Network',
#   'image': 'https://assets.coingecko.com/coins/images/3263/large/CEL_logo.png?1609598753',
#   'current_price': 3.83,
#   'market_cap': 1622010594,
#   'market_cap_rank': 88,
#   'fully_diluted_valuation': None,
#   'total_volume': 2003683,
#   'high_24h': 3.93,
#   'low_24h': 3.79,
#   'price_change_24h': -0.074770455798,
#   'price_change_percentage_24h': -1.91447,
#   'market_cap_change_24h': -32795216.78217292,
#   'market_cap_change_percentage_24h': -1.98182,
#   'circulating_supply': 423415980.3475,
#   'total_supply': 694901823.6871,
#   'max_supply': None,
#   'ath': 8.05,
#   'ath_change_percentage': -52.33515,
#   'ath_date': '2021-06-04T00:04:12.584Z',
#   'atl': 0.02620268,
#   'atl_change_percentage': 14538.16445,
#   'atl_date': '2018-12-07T00:00:00.000Z',
#   'roi': {'times': 11.76924403012524,
#    'currency': 'usd',
#    'percentage': 1176.924403012524},
#   'last_updated': '2021-12-26T05:49:43.973Z'},
#  {'id': 'waves',
#   'symbol': 'waves',
#   'name': 'Waves',
#   'image': 'https://assets.coingecko.com/coins/images/425/large/waves.png?1548386117',
#   'current_price': 15.92,
#   'market_cap': 1591783225,
#   'market_cap_rank': 89,
#   'fully_diluted_valuation': None,
#   'total_volume': 84667155,
#   'high_24h': 16.39,
#   'low_24h': 15.8,
#   'price_change_24h': -0.306179513654,
#   'price_change_percentage_24h': -1.8872,
#   'market_cap_change_24h': -30753251.40766096,
#   'market_cap_change_percentage_24h': -1.89538,
#   'circulating_supply': 100000000.0,
#   'total_supply': 100000000.0,
#   'max_supply': None,
#   'ath': 43.01,
#   'ath_change_percentage': -63.03253,
#   'ath_date': '2021-05-04T06:49:41.528Z',
#   'atl': 0.130878,
#   'atl_change_percentage': 12049.57283,
#   'atl_date': '2016-08-02T00:00:00.000Z',
#   'roi': {'times': 83.66932047105394,
#    'currency': 'usd',
#    'percentage': 8366.932047105394},
#   'last_updated': '2021-12-26T05:49:58.664Z'},
#  {'id': 'ecomi',
#   'symbol': 'omi',
#   'name': 'ECOMI',
#   'image': 'https://assets.coingecko.com/coins/images/4428/large/ECOMI.png?1557928886',
#   'current_price': 0.00652562,
#   'market_cap': 1566750461,
#   'market_cap_rank': 90,
#   'fully_diluted_valuation': None,
#   'total_volume': 4558946,
#   'high_24h': 0.00666092,
#   'low_24h': 0.00639079,
#   'price_change_24h': 6.473e-05,
#   'price_change_percentage_24h': 1.00183,
#   'market_cap_change_24h': 15921655,
#   'market_cap_change_percentage_24h': 1.02665,
#   'circulating_supply': 240092131274.56,
#   'total_supply': 750000000000.0,
#   'max_supply': None,
#   'ath': 0.01343572,
#   'ath_change_percentage': -51.41587,
#   'ath_date': '2021-03-19T17:20:53.999Z',
#   'atl': 3.37e-06,
#   'atl_change_percentage': 193543.42284,
#   'atl_date': '2019-11-04T10:52:42.729Z',
#   'roi': {'times': 12.04861876908919,
#    'currency': 'btc',
#    'percentage': 1204.861876908919},
#   'last_updated': '2021-12-26T05:49:33.677Z'},
#  {'id': 'huobi-token',
#   'symbol': 'ht',
#   'name': 'Huobi Token',
#   'image': 'https://assets.coingecko.com/coins/images/2822/large/huobi-token-logo.png?1547036992',
#   'current_price': 9.92,
#   'market_cap': 1564850105,
#   'market_cap_rank': 91,
#   'fully_diluted_valuation': 4960732918,
#   'total_volume': 114005410,
#   'high_24h': 10.05,
#   'low_24h': 9.81,
#   'price_change_24h': 0.109301,
#   'price_change_percentage_24h': 1.11393,
#   'market_cap_change_24h': 17748271,
#   'market_cap_change_percentage_24h': 1.14719,
#   'circulating_supply': 157723680.25441208,
#   'total_supply': 500000000.0,
#   'max_supply': 500000000.0,
#   'ath': 39.66,
#   'ath_change_percentage': -74.9775,
#   'ath_date': '2021-05-12T14:42:21.586Z',
#   'atl': 0.90862,
#   'atl_change_percentage': 992.21897,
#   'atl_date': '2019-01-30T00:00:00.000Z',
#   'roi': {'times': 9.02168266352329,
#    'currency': 'usd',
#    'percentage': 902.1682663523289},
#   'last_updated': '2021-12-26T05:49:58.281Z'},
#  {'id': 'holotoken',
#   'symbol': 'hot',
#   'name': 'Holo',
#   'image': 'https://assets.coingecko.com/coins/images/3348/large/Holologo_Profile.png?1547037966',
#   'current_price': 0.00871898,
#   'market_cap': 1548661037,
#   'market_cap_rank': 92,
#   'fully_diluted_valuation': None,
#   'total_volume': 106550182,
#   'high_24h': 0.00899823,
#   'low_24h': 0.00868982,
#   'price_change_24h': -0.00024016884,
#   'price_change_percentage_24h': -2.68071,
#   'market_cap_change_24h': -42658653.40225029,
#   'market_cap_change_percentage_24h': -2.68071,
#   'circulating_supply': 177619433541.141,
#   'total_supply': 177619433541.141,
#   'max_supply': None,
#   'ath': 0.03126682,
#   'ath_change_percentage': -72.06594,
#   'ath_date': '2021-04-05T16:04:52.608Z',
#   'atl': 0.0002202,
#   'atl_change_percentage': 3866.45621,
#   'atl_date': '2020-03-13T02:23:01.612Z',
#   'roi': {'times': 8.529270345493877,
#    'currency': 'eth',
#    'percentage': 852.9270345493877},
#   'last_updated': '2021-12-26T05:48:29.415Z'},
#  {'id': 'dash',
#   'symbol': 'dash',
#   'name': 'Dash',
#   'image': 'https://assets.coingecko.com/coins/images/19/large/dash-logo.png?1548385930',
#   'current_price': 146.93,
#   'market_cap': 1543790014,
#   'market_cap_rank': 93,
#   'fully_diluted_valuation': None,
#   'total_volume': 149261691,
#   'high_24h': 153.68,
#   'low_24h': 145.99,
#   'price_change_24h': -3.216955032407,
#   'price_change_percentage_24h': -2.14251,
#   'market_cap_change_24h': -31441243.30913973,
#   'market_cap_change_percentage_24h': -1.99598,
#   'circulating_supply': 10495461.2481798,
#   'total_supply': 18920000.0,
#   'max_supply': None,
#   'ath': 1493.59,
#   'ath_change_percentage': -90.15364,
#   'ath_date': '2017-12-20T00:00:00.000Z',
#   'atl': 0.213899,
#   'atl_change_percentage': 68654.07659,
#   'atl_date': '2014-02-14T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2021-12-26T05:51:04.889Z'},
#  {'id': 'osmosis',
#   'symbol': 'osmo',
#   'name': 'Osmosis',
#   'image': 'https://assets.coingecko.com/coins/images/16724/large/osmo.png?1632763885',
#   'current_price': 5.9,
#   'market_cap': 1507741099,
#   'market_cap_rank': 94,
#   'fully_diluted_valuation': 5904812055,
#   'total_volume': 30477274,
#   'high_24h': 6.0,
#   'low_24h': 5.54,
#   'price_change_24h': 0.290577,
#   'price_change_percentage_24h': 5.17572,
#   'market_cap_change_24h': 76341575,
#   'market_cap_change_percentage_24h': 5.33335,
#   'circulating_supply': 255341082.0,
#   'total_supply': 325000000.0,
#   'max_supply': 1000000000.0,
#   'ath': 7.61,
#   'ath_change_percentage': -22.45683,
#   'ath_date': '2021-09-20T00:00:09.729Z',
#   'atl': 1.24,
#   'atl_change_percentage': 377.93126,
#   'atl_date': '2021-07-20T10:21:24.662Z',
#   'roi': None,
#   'last_updated': '2021-12-26T05:41:14.274Z'},
#  {'id': 'sushi',
#   'symbol': 'sushi',
#   'name': 'Sushi',
#   'image': 'https://assets.coingecko.com/coins/images/12271/large/512x512_Logo_no_chop.png?1606986688',
#   'current_price': 7.32,
#   'market_cap': 1413885762,
#   'market_cap_rank': 95,
#   'fully_diluted_valuation': 1833460267,
#   'total_volume': 288689142,
#   'high_24h': 7.67,
#   'low_24h': 7.2,
#   'price_change_24h': -0.137367556576,
#   'price_change_percentage_24h': -1.84229,
#   'market_cap_change_24h': -24593503.388607264,
#   'market_cap_change_percentage_24h': -1.70969,
#   'circulating_supply': 192789255.8554817,
#   'total_supply': 238940383.23522,
#   'max_supply': 250000000.0,
#   'ath': 23.38,
#   'ath_change_percentage': -68.62719,
#   'ath_date': '2021-03-13T23:44:36.774Z',
#   'atl': 0.475381,
#   'atl_change_percentage': 1442.73058,
#   'atl_date': '2020-11-04T14:53:53.560Z',
#   'roi': None,
#   'last_updated': '2021-12-26T05:49:36.944Z'},
#  {'id': 'msol',
#   'symbol': 'msol',
#   'name': 'Marinade staked SOL',
#   'image': 'https://assets.coingecko.com/coins/images/17752/large/PJ7Scn3.png?1629175951',
#   'current_price': 196.49,
#   'market_cap': 1410554743,
#   'market_cap_rank': 96,
#   'fully_diluted_valuation': 1410554743,
#   'total_volume': 48557645,
#   'high_24h': 200.49,
#   'low_24h': 194.07,
#   'price_change_24h': -2.250510936655,
#   'price_change_percentage_24h': -1.13237,
#   'market_cap_change_24h': -13037383.30343175,
#   'market_cap_change_percentage_24h': -0.91581,
#   'circulating_supply': 7173945.15514004,
#   'total_supply': 7173945.15514004,
#   'max_supply': 7173945.15514004,
#   'ath': 3541.84,
#   'ath_change_percentage': -94.4482,
#   'ath_date': '2021-08-23T22:16:35.076Z',
#   'atl': 42.4,
#   'atl_change_percentage': 363.77258,
#   'atl_date': '2021-08-30T10:27:09.425Z',
#   'roi': None,
#   'last_updated': '2021-12-26T05:49:23.231Z'},
#  {'id': 'compound-governance-token',
#   'symbol': 'comp',
#   'name': 'Compound',
#   'image': 'https://assets.coingecko.com/coins/images/10775/large/COMP.png?1592625425',
#   'current_price': 222.05,
#   'market_cap': 1396342450,
#   'market_cap_rank': 97,
#   'fully_diluted_valuation': 2220504455,
#   'total_volume': 88350034,
#   'high_24h': 234.27,
#   'low_24h': 220.01,
#   'price_change_24h': -12.21705977843,
#   'price_change_percentage_24h': -5.215,
#   'market_cap_change_24h': -75672986.06383848,
#   'market_cap_change_percentage_24h': -5.14077,
#   'circulating_supply': 6288401.933095929,
#   'total_supply': 10000000.0,
#   'max_supply': 10000000.0,
#   'ath': 910.54,
#   'ath_change_percentage': -75.59658,
#   'ath_date': '2021-05-12T02:29:08.794Z',
#   'atl': 61.32,
#   'atl_change_percentage': 262.35585,
#   'atl_date': '2020-06-18T12:54:32.788Z',
#   'roi': None,
#   'last_updated': '2021-12-26T05:50:21.554Z'},
#  {'id': 'iotex',
#   'symbol': 'iotx',
#   'name': 'IoTeX',
#   'image': 'https://assets.coingecko.com/coins/images/3334/large/iotex-logo.png?1547037941',
#   'current_price': 0.142212,
#   'market_cap': 1349709723,
#   'market_cap_rank': 98,
#   'fully_diluted_valuation': 1350483001,
#   'total_volume': 76095477,
#   'high_24h': 0.144681,
#   'low_24h': 0.134965,
#   'price_change_24h': 0.00202342,
#   'price_change_percentage_24h': 1.44335,
#   'market_cap_change_24h': 19716428,
#   'market_cap_change_percentage_24h': 1.48245,
#   'circulating_supply': 9490829322.48387,
#   'total_supply': 9496266827.32,
#   'max_supply': 9496266827.32,
#   'ath': 0.255593,
#   'ath_change_percentage': -43.89984,
#   'ath_date': '2021-11-13T16:54:18.643Z',
#   'atl': 0.00121576,
#   'atl_change_percentage': 11694.10988,
#   'atl_date': '2020-03-13T02:29:47.597Z',
#   'roi': None,
#   'last_updated': '2021-12-26T05:49:26.029Z'},
#  {'id': 'nexo',
#   'symbol': 'nexo',
#   'name': 'NEXO',
#   'image': 'https://assets.coingecko.com/coins/images/3695/large/nexo.png?1548086057',
#   'current_price': 2.4,
#   'market_cap': 1344405424,
#   'market_cap_rank': 99,
#   'fully_diluted_valuation': 2400723928,
#   'total_volume': 5248967,
#   'high_24h': 2.46,
#   'low_24h': 2.38,
#   'price_change_24h': 0.00686051,
#   'price_change_percentage_24h': 0.28659,
#   'market_cap_change_24h': 2569502,
#   'market_cap_change_percentage_24h': 0.19149,
#   'circulating_supply': 560000010.0064,
#   'total_supply': 1000000000.0,
#   'max_supply': 1000000000.0,
#   'ath': 4.07,
#   'ath_change_percentage': -41.19846,
#   'ath_date': '2021-05-12T14:37:47.535Z',
#   'atl': 0.04515276,
#   'atl_change_percentage': 5197.63711,
#   'atl_date': '2018-09-13T00:00:00.000Z',
#   'roi': {'times': 23.00723927972034,
#    'currency': 'usd',
#    'percentage': 2300.723927972034},
#   'last_updated': '2021-12-26T05:49:52.852Z'},
#  {'id': 'true-usd',
#   'symbol': 'tusd',
#   'name': 'TrueUSD',
#   'image': 'https://assets.coingecko.com/coins/images/3449/large/tusd.png?1618395665',
#   'current_price': 1.0,
#   'market_cap': 1314842298,
#   'market_cap_rank': 100,
#   'fully_diluted_valuation': None,
#   'total_volume': 121333542,
#   'high_24h': 1.01,
#   'low_24h': 0.993368,
#   'price_change_24h': 0.00049077,
#   'price_change_percentage_24h': 0.04902,
#   'market_cap_change_24h': 180944,
#   'market_cap_change_percentage_24h': 0.01376,
#   'circulating_supply': 1312618385.04201,
#   'total_supply': 1312618385.04201,
#   'max_supply': None,
#   'ath': 1.62,
#   'ath_change_percentage': -38.07992,
#   'ath_date': '2018-08-26T20:41:09.375Z',
#   'atl': 0.88355,
#   'atl_change_percentage': 13.42703,
#   'atl_date': '2020-03-12T10:47:51.380Z',
#   'roi': None,
#   'last_updated': '2021-12-26T05:50:26.364Z'}]
